# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file='../EXAM_PANDAS/DATA/Pokemon Database.csv'

# %%
POKEMONDF=pd.read_csv(file)

# %%
POKEMONDF
# Out:
#       Pokemon Id  Pokedex Number    Pokemon Name     Classification  \
# 0              1               1     "Bulbasaur"     "Seed Pokémon"
# 1              2               2       "Ivysaur"     "Seed Pokémon"
# 2              3               3      "Venusaur"     "Seed Pokémon"
# 3              4               3      "Venusaur"     "Seed Pokémon"
# 4           1526               3      "Venusaur"     "Seed Pokémon"
# ...          ...             ...             ...                ...
# 1230        1685            1004        "Chi-Yu"  "Ruinous Pokémon"
# 1231        1742            1005  "Roaring Moon"  "Paradox Pokémon"
# 1232        1749            1006  "Iron Valiant"  "Paradox Pokémon"
# 1233        1647            1007      "Koraidon"  "Paradox Pokémon"
# 1234        1648            1008      "Miraidon"  "Paradox Pokémon"
#
#      Alternate Form Name  Original Pokemon ID   Legendary Type  \
# 0                    NaN                  NaN              NaN
# ...

# %%
POKEMONDF['BMI']=round((POKEMONDF['Pokemon Weight']/POKEMONDF['Pokemon Height']**2),2)

# %%
POKEMONDF['Pokedex Number']
# Out:
# 0          1
# 1          2
# 2          3
# 3          3
# 4          3
#         ...
# 1230    1004
# 1231    1005
# 1232    1006
# 1233    1007
# 1234    1008
# Name: Pokedex Number, Length: 1235, dtype: int64

# %%
POKEMONDF=POKEMONDF.drop_duplicates(subset=['Pokedex Number'])
POKEMONDF
# Out:
#       Pokemon Id  Pokedex Number    Pokemon Name     Classification  \
# 0              1               1     "Bulbasaur"     "Seed Pokémon"
# 1              2               2       "Ivysaur"     "Seed Pokémon"
# 2              3               3      "Venusaur"     "Seed Pokémon"
# 5              5               4    "Charmander"   "Lizard Pokémon"
# 6              6               5    "Charmeleon"    "Flame Pokémon"
# ...          ...             ...             ...                ...
# 1230        1685            1004        "Chi-Yu"  "Ruinous Pokémon"
# 1231        1742            1005  "Roaring Moon"  "Paradox Pokémon"
# 1232        1749            1006  "Iron Valiant"  "Paradox Pokémon"
# 1233        1647            1007      "Koraidon"  "Paradox Pokémon"
# 1234        1648            1008      "Miraidon"  "Paradox Pokémon"
#
#      Alternate Form Name  Original Pokemon ID   Legendary Type  \
# 0                    NaN                  NaN              NaN
# ...

# %% [markdown]
# (1) 전설의 포켓몬 구별

# %%
legendary=POKEMONDF[POKEMONDF['Legendary Type'].notna()]

# %%
legendary
# Out:
#       Pokemon Id  Pokedex Number Pokemon Name         Classification  \
# 213          239             144   "Articuno"       "Freeze Pokémon"
# 215         1386             145     "Zapdos"  "Strong Legs Pokémon"
# 217          241             146    "Moltres"        "Flame Pokémon"
# 222           43             150     "Mewtwo"      "Genetic Pokémon"
# 225           42             151        "Mew"  "New Species Pokémon"
# ...          ...             ...          ...                    ...
# 1228        1683            1002  "Chien-Pao"      "Ruinous Pokémon"
# 1229        1682            1003    "Ting-Lu"      "Ruinous Pokémon"
# 1230        1685            1004     "Chi-Yu"      "Ruinous Pokémon"
# 1233        1647            1007   "Koraidon"      "Paradox Pokémon"
# 1234        1648            1008   "Miraidon"      "Paradox Pokémon"
#
#      Alternate Form Name  Original Pokemon ID   Legendary Type  \
# 213                  NaN                  NaN  "Sub-Legendary"
# ...

# %%
normal=POKEMONDF[POKEMONDF['Legendary Type'].isna()]
normal
# Out:
#       Pokemon Id  Pokedex Number    Pokemon Name         Classification  \
# 0              1               1     "Bulbasaur"         "Seed Pokémon"
# 1              2               2       "Ivysaur"         "Seed Pokémon"
# 2              3               3      "Venusaur"         "Seed Pokémon"
# 5              5               4    "Charmander"       "Lizard Pokémon"
# 6              6               5    "Charmeleon"        "Flame Pokémon"
# ...          ...             ...             ...                    ...
# 1223        1725             998    "Baxcalibur"   "Ice Dragon Pokémon"
# 1224        1664             999    "Gimmighoul"   "Coin Chest Pokémon"
# 1226        1681            1000     "Gholdengo"  "Coin Entity Pokémon"
# 1231        1742            1005  "Roaring Moon"      "Paradox Pokémon"
# 1232        1749            1006  "Iron Valiant"      "Paradox Pokémon"
#
#      Alternate Form Name  Original Pokemon ID Legendary Type  Pokemon Height  \
# ...

# %%
normal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 911 entries, 0 to 1232
# Data columns (total 46 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Pokemon Id                         911 non-null    int64
#  1   Pokedex Number                     911 non-null    int64
#  2   Pokemon Name                       911 non-null    object
#  3   Classification                     911 non-null    object
#  4   Alternate Form Name                25 non-null     object
#  5   Original Pokemon ID                25 non-null     float64
#  6   Legendary Type                     0 non-null      object
#  7   Pokemon Height                     911 non-null    float64
#  8   Pokemon Weight                     911 non-null    float64
#  9   Primary Type                       911 non-null    object
#  10  Secondary Type                     463 non-null    object
# ...

# %% [markdown]
# (2) 포켓몬 남녀 성별 분류

# %%
NOSEX=normal[(normal["Male Ratio"]==0) & (normal["Female Ratio"]==0)]

# %%
YESSEX=~(normal["Male Ratio"]==0) | (normal["Female Ratio"]==0)

# %%
type(YESSEX)
# Out:
# pandas.core.series.Series

# %%
NOSEX=normal[(normal["Male Ratio"]==0) & (normal["Female Ratio"]==0)]
MALEFE=normal[(normal["Male Ratio"]==50) & (normal["Female Ratio"]==50)]
MALEONLY=normal[normal["Male Ratio"]==100] 
FEMALEONLY=normal[normal["Female Ratio"]==100]

# %% [markdown]
# ## (2-1) 무성인 포켓몬

# %%
NOSEX #55종
# Out:
#       Pokemon Id  Pokedex Number    Pokemon Name           Classification  \
# 122           46              81     "Magnemite"         "Magnet Pokémon"
# 123         1341              82      "Magneton"         "Magnet Pokémon"
# 148         1620             100       "Voltorb"         "Sphere Pokémon"
# 150          105             101     "Electrode"           "Ball Pokémon"
# 178          216             120        "Staryu"     "Star Shape Pokémon"
# 179          217             121       "Starmie"     "Mysterious Pokémon"
# 197           29             132         "Ditto"      "Transform Pokémon"
# 204          232             137       "Porygon"        "Virtual Pokémon"
# 279          325             201         "Unown"         "Symbol Pokémon"
# 318          357             233      "Porygon2"        "Virtual Pokémon"
# 384          420             292      "Shedinja"           "Shed Pokémon"
# 437          465             337      "Lunatone"      "Meteorite Pokémon"
# ...

# %%
NOSEX['Male Ratio']
# Out:
# 122     0.0
# 123     0.0
# 148     0.0
# 150     0.0
# 178     0.0
# 179     0.0
# 197     0.0
# 204     0.0
# 279     0.0
# 318     0.0
# 384     0.0
# 437     0.0
# 438     0.0
# 443     0.0
# 444     0.0
# 558     0.0
# 559     0.0
# 587     0.0
# 602     0.0
# 609     0.0
# 620     0.0
# 751     0.0
# 752     0.0
# 753     0.0
# 767     0.0
# 775     0.0
# 776     0.0
# 867     0.0
# 954     0.0
# 962     0.0
# 1055    0.0
# 1056    0.0
# 1074    0.0
# 1087    0.0
# 1088    0.0
# 1089    0.0
# 1090    0.0
# 1145    0.0
# 1146    0.0
# 1209    0.0
# 1210    0.0
# 1211    0.0
# 1212    0.0
# 1213    0.0
# 1214    0.0
# 1215    0.0
# 1216    0.0
# 1217    0.0
# 1218    0.0
# 1219    0.0
# 1220    0.0
# 1224    0.0
# 1226    0.0
# 1231    0.0
# 1232    0.0
# Name: Male Ratio, dtype: float64

# %%
NOSEX['Female Ratio']
# Out:
# 122     0.0
# 123     0.0
# 148     0.0
# 150     0.0
# 178     0.0
# 179     0.0
# 197     0.0
# 204     0.0
# 279     0.0
# 318     0.0
# 384     0.0
# 437     0.0
# 438     0.0
# 443     0.0
# 444     0.0
# 558     0.0
# 559     0.0
# 587     0.0
# 602     0.0
# 609     0.0
# 620     0.0
# 751     0.0
# 752     0.0
# 753     0.0
# 767     0.0
# 775     0.0
# 776     0.0
# 867     0.0
# 954     0.0
# 962     0.0
# 1055    0.0
# 1056    0.0
# 1074    0.0
# 1087    0.0
# 1088    0.0
# 1089    0.0
# 1090    0.0
# 1145    0.0
# 1146    0.0
# 1209    0.0
# 1210    0.0
# 1211    0.0
# 1212    0.0
# 1213    0.0
# 1214    0.0
# 1215    0.0
# 1216    0.0
# 1217    0.0
# 1218    0.0
# 1219    0.0
# 1220    0.0
# 1224    0.0
# 1226    0.0
# 1231    0.0
# 1232    0.0
# Name: Female Ratio, dtype: float64

# %% [markdown]
# ## (2-2) 성별이 고른 포켓몬

# %%
MALEFE   #622종
# Out:
#       Pokemon Id  Pokedex Number   Pokemon Name        Classification  \
# 16            32              10     "Caterpie"        "Worm Pokémon"
# 17            23              11      "Metapod"      "Cocoon Pokémon"
# 18            24              12   "Butterfree"   "Butterfly Pokémon"
# 20            31              13       "Weedle"   "Hairy Bug Pokémon"
# 21            30              14       "Kakuna"      "Cocoon Pokémon"
# ...          ...             ...            ...                   ...
# 1207        1690             982  "Dudunsparce"  "Land Snake Pokémon"
# 1208        1686             983    "Kingambit"   "Big Blade Pokémon"
# 1221        1723             996     "Frigibax"     "Ice Fin Pokémon"
# 1222        1724             997     "Arctibax"     "Ice Fin Pokémon"
# 1223        1725             998   "Baxcalibur"  "Ice Dragon Pokémon"
#
#      Alternate Form Name  Original Pokemon ID Legendary Type  Pokemon Height  \
# ...

# %%
MALEFE['Male Ratio']
# Out:
# 16      50.0
# 17      50.0
# 18      50.0
# 20      50.0
# 21      50.0
#         ...
# 1207    50.0
# 1208    50.0
# 1221    50.0
# 1222    50.0
# 1223    50.0
# Name: Male Ratio, Length: 622, dtype: float64

# %%
MALEFE['Female Ratio']
# Out:
# 16      50.0
# 17      50.0
# 18      50.0
# 20      50.0
# 21      50.0
#         ...
# 1207    50.0
# 1208    50.0
# 1221    50.0
# 1222    50.0
# 1223    50.0
# Name: Female Ratio, Length: 622, dtype: float64

# %% [markdown]
# ## (2-3) 남탕

# %%
MALEONLY #25종
# Out:
#       Pokemon Id  Pokedex Number      Pokemon Name        Classification  \
# 50            48              32  "Nidoran (Male)"  "Poison Pin Pokémon"
# 51            49              33        "Nidorino"  "Poison Pin Pokémon"
# 52            50              34        "Nidoking"       "Drill Pokémon"
# 162          140             106       "Hitmonlee"     "Kicking Pokémon"
# 163          141             107      "Hitmonchan"    "Punching Pokémon"
# 188         1671             128          "Tauros"   "Wild Bull Pokémon"
# 321          360             236         "Tyrogue"     "Scuffle Pokémon"
# 322          361             237       "Hitmontop"   "Handstand Pokémon"
# 410          441             313         "Volbeat"     "Firefly Pokémon"
# 482          502             374          "Beldum"   "Iron Ball Pokémon"
# 483          503             375          "Metang"   "Iron Claw Pokémon"
# 484          504             376       "Metagross"    "Iron Leg Pokémon"
# ...

# %% [markdown]
# ## (2-3) 여탕

# %%
FEMALEONLY #34종
# Out:
#       Pokemon Id  Pokedex Number        Pokemon Name          Classification  \
# 47            33              29  "Nidoran (Female)"    "Poison Pin Pokémon"
# 48            17              30          "Nidorina"    "Poison Pin Pokémon"
# 49            18              31         "Nidoqueen"         "Drill Pokémon"
# 170          147             113           "Chansey"           "Egg Pokémon"
# 172          211             115        "Kangaskhan"        "Parent Pokémon"
# 183          220             124              "Jynx"   "Human Shape Pokémon"
# 323          362             238          "Smoochum"          "Kiss Pokémon"
# 326          365             241           "Miltank"      "Milk Cow Pokémon"
# 327          366             242           "Blissey"     "Happiness Pokémon"
# 411          442             314          "Illumise"       "Firefly Pokémon"
# 532         1568             413          "Wormadam"       "Bagworm Pokémon"
# ...

# %% [markdown]
# ## (2-4) 수컷 고위험군(남:87.5/여:12.5)

# %%
MALEOVER=normal[normal["Male Ratio"]==87.5]  #129종

# %%
MALEOVER
# Out:
#       Pokemon Id  Pokedex Number  Pokemon Name        Classification  \
# 0              1               1   "Bulbasaur"        "Seed Pokémon"
# 1              2               2     "Ivysaur"        "Seed Pokémon"
# 2              3               3    "Venusaur"        "Seed Pokémon"
# 5              5               4  "Charmander"      "Lizard Pokémon"
# 6              6               5  "Charmeleon"       "Flame Pokémon"
# ...          ...             ...           ...                   ...
# 1130        1669             910    "Crocalor"   "Fire Croc Pokémon"
# 1131        1670             911  "Skeledirge"      "Singer Pokémon"
# 1132        1644             912      "Quaxly"    "Duckling Pokémon"
# 1133        1674             913    "Quaxwell"  "Practicing Pokémon"
# 1134        1675             914   "Quaquaval"      "Dancer Pokémon"
#
#      Alternate Form Name  Original Pokemon ID Legendary Type  Pokemon Height  \
# ...

# %% [markdown]
# ## (2-4) 암컷 고위험군(남:12.5/여:87.5)

# %%
FEMALEOVER=normal[normal["Female Ratio"]==87.5] #2종

# %%
FEMALEOVER
# Out:
#      Pokemon Id  Pokedex Number Pokemon Name      Classification  \
# 828        1084             667     "Litleo"  "Lion Cub Pokémon"
# 829        1085             668     "Pyroar"     "Royal Pokémon"
#
#     Alternate Form Name  Original Pokemon ID Legendary Type  Pokemon Height  \
# 828                 NaN                  NaN            NaN             0.6
# 829                 NaN                  NaN            NaN             1.5
#
#      Pokemon Weight Primary Type  ... EV Yield Total Catch Rate  \
# 828            13.5       "Fire"  ...              1        220
# 829            81.5       "Fire"  ...              2         65
#
#     Experience Growth Experience Growth Total Primary Egg Group  \
# 828     "Medium Slow"                 1059860           "Field"
# 829     "Medium Slow"                 1059860           "Field"
#
#     Secondary Egg Group Egg Cycle Count Pre-Evolution Pokemon Id  \
# 828                 NaN              20                      NaN
# ...

# %% [markdown]
# ## (2-4) 수컷 위험군(남:25/여:75)

# %%
MALEOVER2=normal[normal["Male Ratio"]==25]   #25종

# %%
MALEOVER2
# Out:
#       Pokemon Id  Pokedex Number  Pokemon Name         Classification  \
# 53            52              35    "Clefairy"        "Fairy Pokémon"
# 54            53              36    "Clefable"        "Fairy Pokémon"
# 55            54              37      "Vulpix"          "Fox Pokémon"
# 57            56              38   "Ninetales"          "Fox Pokémon"
# 59            59              39  "Jigglypuff"      "Balloon Pokémon"
# 60            60              40  "Wigglytuff"      "Balloon Pokémon"
# 248           51             173      "Cleffa"   "Star Shape Pokémon"
# 249           58             174   "Igglybuff"      "Balloon Pokémon"
# 288          333             209    "Snubbull"        "Fairy Pokémon"
# 289          334             210    "Granbull"        "Fairy Pokémon"
# 305          346             222     "Corsola"        "Coral Pokémon"
# 390          426             298     "Azurill"    "Polka Dot Pokémon"
# ...

# %% [markdown]
# ## (2-4) 암컷 위험군(남:25/여:75)

# %%
FEMALEOVER2=normal[normal["Male Ratio"]==25]   #25종

# %%
FEMALEOVER2
# Out:
#       Pokemon Id  Pokedex Number  Pokemon Name         Classification  \
# 53            52              35    "Clefairy"        "Fairy Pokémon"
# 54            53              36    "Clefable"        "Fairy Pokémon"
# 55            54              37      "Vulpix"          "Fox Pokémon"
# 57            56              38   "Ninetales"          "Fox Pokémon"
# 59            59              39  "Jigglypuff"      "Balloon Pokémon"
# 60            60              40  "Wigglytuff"      "Balloon Pokémon"
# 248           51             173      "Cleffa"   "Star Shape Pokémon"
# 249           58             174   "Igglybuff"      "Balloon Pokémon"
# 288          333             209    "Snubbull"        "Fairy Pokémon"
# 289          334             210    "Granbull"        "Fairy Pokémon"
# 305          346             222     "Corsola"        "Coral Pokémon"
# 390          426             298     "Azurill"    "Polka Dot Pokémon"
# ...

# %%
import matplotlib.pyplot as plt           #그래프 관련 모듈
import matplotlib as mpl                  #패키지 관련 
import matplotlib.font_manager as fm      #패키지 리소스 즉 자원 중 폰트 관련
                                        
import pandas as pd

# %%
# 폰트 경로 저장
font_path=r'C:\Windows\Fonts\gulim.ttc'

# %%
#matplotlib 패키지에 한글 폰트 설정
myFont=fm.FontProperties(fname=font_path).get_name()
mpl.rc('font', family=myFont)

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = [
          "25종 MALEONLY 남탕(2.3%)",
          "34종 FEMALEONLY 여탕(3.1%)",
          "129종 MALEOVER 수컷고위험군(11.8%)",
          "2종 FEMALEOVER 암컷고위험군(0.2%)",
          "25종 MALEOVER2 수컷위험군(2.3%)",
          "25종 FEMALEOVER2 암컷위험군(2.3%)",
          "55종  무성(5.0%)"
          ]

data = [25,34,129,2,25,19,55]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(xycoords='data', textcoords='data', arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                 horizontalalignment=horizontalalignment, **kw)

ax.set_title(" 50:50성비를 제외한 성비 종류 ")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(15, 10), subplot_kw=dict(aspect="equal"))

recipe = ["797 MALEFE 남녀골고루(73%)",
          "25 MALEONLY 남탕(2.3%)",
          "34 FEMALEONLY 여탕(3.1%)",
          "129 MALEOVER 수컷고위험군(11.8%)",
          "2 FEMALEOVER 암컷고위험군(0.2%)",
          "25 MALEOVER2 수컷위험군(2.3%)",
          "25 FEMALEOVER2 암컷위험군(2.3%)",
          "55  무성(5.0%)"
          ]

data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d})"


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data), textprops=dict(color="w", fontsize='xx-small'))

ax.legend(wedges, ingredients,
          title="포켓몬 전체 성별",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=10, weight="bold")

ax.set_title("성비 종류 ", size=30)

plt.show()

# %% [markdown]
# (3) BMI

# %%
round((POKEMONDF['Pokemon Weight']/POKEMONDF['Pokemon Height']**2),2)
# Out:
# 0       14.08
# 1       13.00
# 2       25.00
# 5       23.61
# 6       15.70
#         ...
# 1230    30.62
# 1231    95.00
# 1232    17.86
# 1233    48.48
# 1234    19.59
# Length: 1008, dtype: float64

# %%
POKEMONDF
# Out:
#       Pokemon Id  Pokedex Number    Pokemon Name     Classification  \
# 0              1               1     "Bulbasaur"     "Seed Pokémon"
# 1              2               2       "Ivysaur"     "Seed Pokémon"
# 2              3               3      "Venusaur"     "Seed Pokémon"
# 5              5               4    "Charmander"   "Lizard Pokémon"
# 6              6               5    "Charmeleon"    "Flame Pokémon"
# ...          ...             ...             ...                ...
# 1230        1685            1004        "Chi-Yu"  "Ruinous Pokémon"
# 1231        1742            1005  "Roaring Moon"  "Paradox Pokémon"
# 1232        1749            1006  "Iron Valiant"  "Paradox Pokémon"
# 1233        1647            1007      "Koraidon"  "Paradox Pokémon"
# 1234        1648            1008      "Miraidon"  "Paradox Pokémon"
#
#      Alternate Form Name  Original Pokemon ID   Legendary Type  \
# 0                    NaN                  NaN              NaN
# ...

# %% [markdown]
# ## (3-1) 비만도 기준

# %% [markdown]
# # BMI가 18.5이하라면 마름, 25 이상이면 비만으로 간주한다

# %% [markdown]
# ## (3-1-1) 비만 수컷

# %%
MALEONLYOBESITY=MALEONLY[MALEONLY['BMI']>=25]  # 남탕 중 16종

# %%
MALEONLYOBESITY2=MALEOVER[MALEOVER['BMI']>=25] #고위험군(남) 중 83종

# %%
MALEONLYOBESITY3=MALEOVER2[MALEOVER2['BMI']>=25] #위험군(남) 중 11종

# %%
MALEONLYOBESITY #16종
# Out:
#       Pokemon Id  Pokedex Number      Pokemon Name        Classification  \
# 50            48              32  "Nidoran (Male)"  "Poison Pin Pokémon"
# 52            50              34        "Nidoking"       "Drill Pokémon"
# 163          141             107      "Hitmonchan"    "Punching Pokémon"
# 188         1671             128          "Tauros"   "Wild Bull Pokémon"
# 321          360             236         "Tyrogue"     "Scuffle Pokémon"
# 410          441             313         "Volbeat"     "Firefly Pokémon"
# 482          502             374          "Beldum"   "Iron Ball Pokémon"
# 483          503             375          "Metang"   "Iron Claw Pokémon"
# 484          504             376       "Metagross"    "Iron Leg Pokémon"
# 535          612             414          "Mothim"        "Moth Pokémon"
# 679          872             538           "Throh"        "Judo Pokémon"
# 780         1001             627         "Rufflet"      "Eaglet Pokémon"
# ...

# %%
MALEONLYOBESITY2  #83종
# Out:
#       Pokemon Id  Pokedex Number  Pokemon Name          Classification  \
# 2              3               3    "Venusaur"          "Seed Pokémon"
# 7              7               6   "Charizard"         "Flame Pokémon"
# 11            10               7    "Squirtle"   "Tiny Turtle Pokémon"
# 13            12               9   "Blastoise"     "Shellfish Pokémon"
# 198          228             133       "Eevee"     "Evolution Pokémon"
# ...          ...             ...           ...                     ...
# 1005        1445             816      "Sobble"  "Water Lizard Pokémon"
# 1126        1642             906  "Sprigatito"     "Grass Cat Pokémon"
# 1129        1643             909     "Fuecoco"     "Fire Croc Pokémon"
# 1130        1669             910    "Crocalor"     "Fire Croc Pokémon"
# 1131        1670             911  "Skeledirge"        "Singer Pokémon"
#
#      Alternate Form Name  Original Pokemon ID Legendary Type  Pokemon Height  \
# ...

# %%
MALEONLYOBESITY3 #11종
# Out:
#      Pokemon Id  Pokedex Number Pokemon Name         Classification  \
# 55           54              37     "Vulpix"          "Fox Pokémon"
# 248          51             173     "Cleffa"   "Star Shape Pokémon"
# 390         426             298    "Azurill"    "Polka Dot Pokémon"
# 392         428             300     "Skitty"       "Kitten Pokémon"
# 393         429             301   "Delcatty"         "Prim Pokémon"
# 554         630             432    "Purugly"    "Tiger Cat Pokémon"
# 724         941             572   "Minccino"   "Chinchilla Pokémon"
# 725         942             573   "Cinccino"        "Scarf Pokémon"
# 726         943             574    "Gothita"     "Fixation Pokémon"
# 727         944             575  "Gothorita"   "Manipulate Pokémon"
# 944        1292             764     "Comfey"  "Posy Picker Pokémon"
#
#     Alternate Form Name  Original Pokemon ID Legendary Type  Pokemon Height  \
# ...

# %% [markdown]
# ## (3-1-1) 비만 암컷

# %%
FEMALEONLYOBESITY=FEMALEONLY[FEMALEONLY['BMI']>=25]  #17종

# %%
FEMALEONLYOBESITY2=FEMALEOVER[FEMALEOVER['BMI']>=25] #2종

# %%
FEMALEONLYOBESITY3=FEMALEOVER2[FEMALEOVER2['BMI']>=25] # 16종

# %%
FEMALEONLYOBESITY
# Out:
#       Pokemon Id  Pokedex Number        Pokemon Name          Classification  \
# 47            33              29  "Nidoran (Female)"    "Poison Pin Pokémon"
# 48            17              30          "Nidorina"    "Poison Pin Pokémon"
# 49            18              31         "Nidoqueen"         "Drill Pokémon"
# 170          147             113           "Chansey"           "Egg Pokémon"
# 323          362             238          "Smoochum"          "Kiss Pokémon"
# 326          365             241           "Miltank"      "Milk Cow Pokémon"
# 411          442             314          "Illumise"       "Firefly Pokémon"
# 532         1568             413          "Wormadam"       "Bagworm Pokémon"
# 537          614             416         "Vespiquen"       "Beehive Pokémon"
# 562          638             440           "Happiny"     "Playhouse Pokémon"
# 689          882             548           "Petilil"          "Bulb Pokémon"
# ...

# %%
FEMALEONLYOBESITY2
# Out:
#      Pokemon Id  Pokedex Number Pokemon Name      Classification  \
# 828        1084             667     "Litleo"  "Lion Cub Pokémon"
# 829        1085             668     "Pyroar"     "Royal Pokémon"
#
#     Alternate Form Name  Original Pokemon ID Legendary Type  Pokemon Height  \
# 828                 NaN                  NaN            NaN             0.6
# 829                 NaN                  NaN            NaN             1.5
#
#      Pokemon Weight Primary Type  ... EV Yield Total Catch Rate  \
# 828            13.5       "Fire"  ...              1        220
# 829            81.5       "Fire"  ...              2         65
#
#     Experience Growth Experience Growth Total Primary Egg Group  \
# 828     "Medium Slow"                 1059860           "Field"
# 829     "Medium Slow"                 1059860           "Field"
#
#     Secondary Egg Group Egg Cycle Count Pre-Evolution Pokemon Id  \
# 828                 NaN              20                      NaN
# ...

# %%
FEMALEONLYOBESITY3  #16종
# Out:
#      Pokemon Id  Pokedex Number Pokemon Name         Classification  \
# 55           54              37     "Vulpix"          "Fox Pokémon"
# 248          51             173     "Cleffa"   "Star Shape Pokémon"
# 390         426             298    "Azurill"    "Polka Dot Pokémon"
# 392         428             300     "Skitty"       "Kitten Pokémon"
# 393         429             301   "Delcatty"         "Prim Pokémon"
# 554         630             432    "Purugly"    "Tiger Cat Pokémon"
# 724         941             572   "Minccino"   "Chinchilla Pokémon"
# 725         942             573   "Cinccino"        "Scarf Pokémon"
# 726         943             574    "Gothita"     "Fixation Pokémon"
# 727         944             575  "Gothorita"   "Manipulate Pokémon"
# 944        1292             764     "Comfey"  "Posy Picker Pokémon"
#
#     Alternate Form Name  Original Pokemon ID Legendary Type  Pokemon Height  \
# ...

# %% [markdown]
# # (3-1-3) 저체중 수컷

# %%
MALEONLYLOW=MALEONLY[MALEONLY['BMI']<=18.5]  # 2종

# %%
MALEONLYLOW2=MALEOVER[MALEOVER['BMI']<=18.5] #고위험군(남) 중 83종

# %%
MALEONLYLOW3=MALEOVER2[MALEOVER2['BMI']<=18.5] #위험군(남) 중

# %%
MALEONLYLOW
# Out:
#      Pokemon Id  Pokedex Number Pokemon Name     Classification  \
# 491        1399             381     "Latios"      "Eon Pokémon"
# 781        1002             628   "Braviary"  "Valiant Pokémon"
#
#     Alternate Form Name  Original Pokemon ID Legendary Type  Pokemon Height  \
# 491              "Mega"                509.0            NaN             2.3
# 781                 NaN                  NaN            NaN             1.5
#
#      Pokemon Weight Primary Type  ... EV Yield Total Catch Rate  \
# 491            70.0     "Dragon"  ...              3          3
# 781            41.0     "Normal"  ...              2         60
#
#     Experience Growth Experience Growth Total     Primary Egg Group  \
# 491            "Slow"                 1250000  "No Eggs Discovered"
# 781            "Slow"                 1250000              "Flying"
#
#     Secondary Egg Group Egg Cycle Count Pre-Evolution Pokemon Id  \
# 491                 NaN             120                      NaN
# ...

# %%
MALEONLYLOW2 #29종
# Out:
#       Pokemon Id  Pokedex Number   Pokemon Name          Classification  \
# 0              1               1    "Bulbasaur"          "Seed Pokémon"
# 1              2               2      "Ivysaur"          "Seed Pokémon"
# 6              6               5   "Charmeleon"         "Flame Pokémon"
# 209          237             142   "Aerodactyl"        "Fossil Pokémon"
# 211         1545             143      "Snorlax"      "Sleeping Pokémon"
# 226          245             152    "Chikorita"          "Leaf Pokémon"
# 227          246             153      "Bayleef"          "Leaf Pokémon"
# 235          253             160   "Feraligatr"       "Big Jaw Pokémon"
# 250          264             175       "Togepi"    "Spike Ball Pokémon"
# 251          265             176      "Togetic"     "Happiness Pokémon"
# 340          382             254     "Sceptile"        "Forest Pokémon"
# 342          383             255      "Torchic"         "Chick Pokémon"
# ...

# %%
MALEONLYLOW3 #7종
# Out:
#       Pokemon Id  Pokedex Number  Pokemon Name     Classification  \
# 57            56              38   "Ninetales"      "Fox Pokémon"
# 60            60              40  "Wigglytuff"  "Balloon Pokémon"
# 249           58             174   "Igglybuff"  "Balloon Pokémon"
# 305          346             222     "Corsola"    "Coral Pokémon"
# 553          629             431     "Glameow"    "Catty Pokémon"
# 915         1267             741    "Oricorio"  "Dancing Pokémon"
# 1067        1390             864     "Cursola"    "Coral Pokémon"
#
#      Alternate Form Name  Original Pokemon ID Legendary Type  Pokemon Height  \
# 57                   NaN                  NaN            NaN             1.1
# 60                   NaN                  NaN            NaN             1.0
# 249                  NaN                  NaN            NaN             0.3
# 305                  NaN                  NaN            NaN             0.6
# ...

# %% [markdown]
# # (3-1-4) 저체중 암컷

# %%
FEMALEONLYLOW=FEMALEONLY[FEMALEONLY['BMI']<=18.5]   #13종

# %%
FEMALEONLYLOW2=FEMALEOVER[FEMALEOVER['BMI']<=18.5] #0종

# %%
FEMALEONLYLOW3=FEMALEOVER2[FEMALEOVER2['BMI']<=18.5] #0종

# %%
FEMALEONLYLOW
# Out:
#       Pokemon Id  Pokedex Number   Pokemon Name          Classification  \
# 172          211             115   "Kangaskhan"        "Parent Pokémon"
# 608          728             478     "Froslass"     "Snow Land Pokémon"
# 690          883             549    "Lilligant"     "Flowering Pokémon"
# 830         1086             669      "Flabébé"  "Single Bloom Pokémon"
# 832         1089             671      "Florges"        "Garden Pokémon"
# 938         1285             758     "Salazzle"  "Toxic Lizard Pokémon"
# 942         1290             762      "Steenee"         "Fruit Pokémon"
# 943         1291             763     "Tsareena"         "Fruit Pokémon"
# 1058        1516             857      "Hattrem"        "Serene Pokémon"
# 1059        1517             858    "Hatterene"        "Silent Pokémon"
# 1071        1483             868      "Milcery"         "Cream Pokémon"
# 1072        1484             869     "Alcremie"         "Cream Pokémon"
# ...

# %%
FEMALEONLYLOW2
# Out:
# Empty DataFrame
# Columns: [Pokemon Id, Pokedex Number, Pokemon Name, Classification, Alternate Form Name, Original Pokemon ID, Legendary Type, Pokemon Height, Pokemon Weight, Primary Type, Secondary Type, Primary Ability, Primary Ability Description, Secondary Ability, Secondary Ability Description, Hidden Ability, Hidden Ability Description, Special Event Ability, Special Event Ability Description, Male Ratio, Female Ratio, Base Happiness, Game(s) of Origin, Health Stat, Attack Stat, Defense Stat, Special Attack Stat, Special Defense Stat, Speed Stat, Base Stat Total, Health EV, Attack EV, Defense EV, Special Attack EV, Special Defense EV, Speed EV, EV Yield Total, Catch Rate, Experience Growth, Experience Growth Total, Primary Egg Group, Secondary Egg Group, Egg Cycle Count, Pre-Evolution Pokemon Id, Evolution Details, BMI]
# Index: []
#
# [0 rows x 46 columns]

# %%
FEMALEONLYLOW3
# Out:
#       Pokemon Id  Pokedex Number  Pokemon Name     Classification  \
# 57            56              38   "Ninetales"      "Fox Pokémon"
# 60            60              40  "Wigglytuff"  "Balloon Pokémon"
# 249           58             174   "Igglybuff"  "Balloon Pokémon"
# 305          346             222     "Corsola"    "Coral Pokémon"
# 553          629             431     "Glameow"    "Catty Pokémon"
# 915         1267             741    "Oricorio"  "Dancing Pokémon"
# 1067        1390             864     "Cursola"    "Coral Pokémon"
#
#      Alternate Form Name  Original Pokemon ID Legendary Type  Pokemon Height  \
# 57                   NaN                  NaN            NaN             1.1
# 60                   NaN                  NaN            NaN             1.0
# 249                  NaN                  NaN            NaN             0.3
# 305                  NaN                  NaN            NaN             0.6
# ...

# %% [markdown]
# # 수컷 비정상 성비 중 비만 데이터

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.patches import ConnectionPatch

# make figure and assign axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 5))
fig.subplots_adjust(wspace=0)

# pie chart parameters
overall_ratios = [25/179, 129/179, 25/179]
labels = ['남탕', '고위험군(남)', '위험군(남)']
explode = [0.1, 0, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * overall_ratios[0]
wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels, explode=explode)

# bar chart parameters
age_ratios = [16/25,9/25]
age_labels = ['비만','비만아님']
bottom = 1
width = .2

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
    bottom -= height
    bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax2.set_title('남 불균형  중 남탕의 비만 비율')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center, r = wedges[0].center, wedges[0].r
bar_height = sum(age_ratios)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.patches import ConnectionPatch

# make figure and assign axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 5))
fig.subplots_adjust(wspace=0)

# pie chart parameters
overall_ratios = [129/179,25/179, 25/179]
labels = ['고위험군(남)','남탕', '위험군(남)']
explode = [0.1, 0, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * overall_ratios[0]
wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels, explode=explode)

# bar chart parameters
age_ratios = [83/129,46/129]
age_labels = ['비만','비만아님']
bottom = 1
width = .2

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
    bottom -= height
    bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax2.set_title('남 불균형  중 고위험군(남)의 비만 비율')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center, r = wedges[0].center, wedges[0].r
bar_height = sum(age_ratios)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.patches import ConnectionPatch

# make figure and assign axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 5))
fig.subplots_adjust(wspace=0)

# pie chart parameters
overall_ratios = [ 25/179,129/179,25/179]
labels = ['위험군(남)','고위험군(남)','남탕']
explode = [0.1, 0, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * overall_ratios[0]
wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels, explode=explode)

# bar chart parameters
age_ratios = [11/25,14/25]
age_labels = ['비만','비만아님']
bottom = 1
width = .2

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
    bottom -= height
    bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax2.set_title('남 불균형  중 고위험군(남)의 비만 비율')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center, r = wedges[0].center, wedges[0].r
bar_height = sum(age_ratios)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

plt.show()

# %% [markdown]
# # 암컷 비정상 성비 중 비만 데이터

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.patches import ConnectionPatch

# make figure and assign axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 5))
fig.subplots_adjust(wspace=0)

# pie chart parameters
overall_ratios = [34/61, 2/61, 11/61]
labels = ['여탕', '고위험군(여)', '위험군(여)']
explode = [0.1, 0, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * overall_ratios[0]
wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels, explode=explode)

# bar chart parameters
age_ratios = [17/34,17/34]
age_labels = ['비만','비만아님']
bottom = 1
width = .2

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
    bottom -= height
    bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax2.set_title('여 불균형  중 여탕의 비만 비율')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center, r = wedges[0].center, wedges[0].r
bar_height = sum(age_ratios)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.patches import ConnectionPatch

# make figure and assign axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 5))
fig.subplots_adjust(wspace=0)

# pie chart parameters
overall_ratios = [2/56, 34/56, 19/56]
labels = ['고위험군(여)','여탕', '위험군(여)']
explode = [0.1, 0, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * overall_ratios[0]
wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels, explode=explode)

# bar chart parameters
age_ratios = [2/2,0/2]
age_labels = ['비만','비만아님']
bottom = 1
width = .2

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
    bottom -= height
    bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax2.set_title('여 불균형  중 고위험군(여)의 비만 비율')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center, r = wedges[0].center, wedges[0].r
bar_height = sum(age_ratios)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.patches import ConnectionPatch

# make figure and assign axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 5))
fig.subplots_adjust(wspace=0)

# pie chart parameters
overall_ratios = [19/56,2/56, 34/56]
labels = ['위험군(여)','고위험군(여)','여탕']
explode = [0.1, 0, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * overall_ratios[0]
wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels, explode=explode)

# bar chart parameters
age_ratios = [16/19,3/19]
age_labels = ['비만','비만아님']
bottom = 1
width = .2

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
    bottom -= height
    bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax2.set_title('여 불균형  중 위험군(여))의 비만 비율')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center, r = wedges[0].center, wedges[0].r
bar_height = sum(age_ratios)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

plt.show()
