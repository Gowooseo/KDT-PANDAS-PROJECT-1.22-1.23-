# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file2='../EXAM_PANDAS_MATPLOT/Day_0119/pokemondata.csv'
file3='../EXAM_PANDAS_MATPLOT/DATA/포켓몬 GO.json'

# %%
POKEMONDF=pd.read_csv(file2)
POKEMONgoDF=pd.read_json(file3)

# %%
POKEMONDF=POKEMONDF.set_index('Name')

# %%
POKEMONDF=POKEMONDF.drop(['Unnamed: 0','#'],axis=1)

# %%
POKEMONDF
# Out:
#                                     Type  Total   HP  Attack  Defense  \
# Name
# Bulbasaur                  Grass  Poison    318   45      49       49
# Ivysaur                    Grass  Poison    405   60      62       63
# Venusaur                   Grass  Poison    525   80      82       83
# Venusaur  Mega Venusaur    Grass  Poison    625   80     100      123
# Charmander                          Fire    309   39      52       43
# ...                                  ...    ...  ...     ...      ...
# Iron Crown                Steel  Psychic    590   90      72      100
# Terapagos  Normal Form            Normal    450   90      65       85
# Terapagos  Terastal Form          Normal    600   95      95      110
# Terapagos  Stellar Form           Normal    700  160     105      110
# Pecharunt                  Poison  Ghost    600   88      88      160
#
#                           Sp. Atk  Sp. Def  Speed
# Name
# Bulbasaur                      65       65     45
# ...

# %%
POKEMONDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1215 entries, Bulbasaur to Pecharunt
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Type     1215 non-null   object
#  1   Total    1215 non-null   int64
#  2   HP       1215 non-null   int64
#  3   Attack   1215 non-null   int64
#  4   Defense  1215 non-null   int64
#  5   Sp. Atk  1215 non-null   int64
#  6   Sp. Def  1215 non-null   int64
#  7   Speed    1215 non-null   int64
# dtypes: int64(7), object(1)
# memory usage: 85.4+ KB

# %%
POKEMONDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1215 entries, Bulbasaur to Pecharunt
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Type     1215 non-null   object
#  1   Total    1215 non-null   int64
#  2   HP       1215 non-null   int64
#  3   Attack   1215 non-null   int64
#  4   Defense  1215 non-null   int64
#  5   Sp. Atk  1215 non-null   int64
#  6   Sp. Def  1215 non-null   int64
#  7   Speed    1215 non-null   int64
# dtypes: int64(7), object(1)
# memory usage: 85.4+ KB

# %%
POKEMONDF['Type'].value_counts()
# Out:
# Type
# Normal             82
# Water              81
# Psychic            47
# Grass              47
# Fire               37
#                    ..
# Fire  Dark          1
# Fighting  Ice       1
# Normal  Dragon      1
# Psychic  Dragon     1
# Poison  Ghost       1
# Name: count, Length: 221, dtype: int64

# %%
POKEMONDF.isnull().sum()
# Out:
# Type       0
# Total      0
# HP         0
# Attack     0
# Defense    0
# Sp. Atk    0
# Sp. Def    0
# Speed      0
# dtype: int64

# %%
POKEMONDF.nunique
# Out:
# <bound method DataFrame.nunique of                                     Type  Total   HP  Attack  Defense  \
# Name
# Bulbasaur                  Grass  Poison    318   45      49       49
# Ivysaur                    Grass  Poison    405   60      62       63
# Venusaur                   Grass  Poison    525   80      82       83
# Venusaur  Mega Venusaur    Grass  Poison    625   80     100      123
# Charmander                          Fire    309   39      52       43
# ...                                  ...    ...  ...     ...      ...
# Iron Crown                Steel  Psychic    590   90      72      100
# Terapagos  Normal Form            Normal    450   90      65       85
# Terapagos  Terastal Form          Normal    600   95      95      110
# Terapagos  Stellar Form           Normal    700  160     105      110
# Pecharunt                  Poison  Ghost    600   88      88      160
#
#                           Sp. Atk  Sp. Def  Speed
# Name
# ...

# %% [markdown]
# 600족 종류별 타입 조사

# %%
E600CONDITION=POKEMONDF["Total"]==600

# %%
E600DF=POKEMONDF[E600CONDITION]
E600DF
# Out:
#                                        Type  Total   HP  Attack  Defense  \
# Name
# Alakazam  Mega Alakazam             Psychic    600   55      50       65
# Gengar  Mega Gengar           Ghost  Poison    600   60      65       80
# Pinsir  Mega Pinsir             Bug  Flying    600   65     155      120
# Dragonite                    Dragon  Flying    600   91     134       95
# Mew                                 Psychic    600  100     100      100
# Scizor  Mega Scizor              Bug  Steel    600   70     150      140
# Heracross  Mega Heracross     Bug  Fighting    600   80     185      115
# Houndoom  Mega Houndoom          Dark  Fire    600   75      90       90
# Tyranitar                        Rock  Dark    600  100     134      110
# Celebi                       Psychic  Grass    600  100     100      100
# Salamence                    Dragon  Flying    600   95     135       80
# Metagross                    Steel  Psychic    600   80     135      130
# ...

# %%
E600DF['Type'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#600족 갖고 놀기

# %%
E600DF['Type'].plot

# %%
E600DF[E600DF['Type'].str.contains('Dragon')]
# Out:
#                                     Type  Total   HP  Attack  Defense  \
# Name
# Dragonite                 Dragon  Flying    600   91     134       95
# Salamence                 Dragon  Flying    600   95     135       80
# Latias                   Dragon  Psychic    600   80      80       90
# Latios                   Dragon  Psychic    600   80      90       80
# Garchomp                  Dragon  Ground    600  108     130       95
# Hydreigon                   Dark  Dragon    600   92     105       90
# Goodra                            Dragon    600   90     100       70
# Goodra  Hisuian Goodra     Steel  Dragon    600   80     100      100
# Zygarde  50% Forme        Dragon  Ground    600  108     100      121
# Kommo-o                 Dragon  Fighting    600   75     110      125
# Dragapult                  Dragon  Ghost    600   88     120       75
# Baxcalibur                   Dragon  Ice    600  115     145       92
# ...

# %% [markdown]
# ### (1) 타입별 분류

# %%
POKEMONDF["Type"].str.split()[0][0]
# Out:
# 'Grass'

# %%
type( POKEMONDF["Type"].str.split() )
# Out:
# pandas.core.series.Series

# %%
typeDF=POKEMONDF["Type"].str.split(expand=True)
typeDF.columns=['Type1', 'Type2']
typeDF
# Out:
#                            Type1    Type2
# Name
# Bulbasaur                  Grass   Poison
# Ivysaur                    Grass   Poison
# Venusaur                   Grass   Poison
# Venusaur  Mega Venusaur    Grass   Poison
# Charmander                  Fire     None
# ...                          ...      ...
# Iron Crown                 Steel  Psychic
# Terapagos  Normal Form    Normal     None
# Terapagos  Terastal Form  Normal     None
# Terapagos  Stellar Form   Normal     None
# Pecharunt                 Poison    Ghost
#
# [1215 rows x 2 columns]

# %%
POKEMONDF2=pd.concat([POKEMONDF, typeDF], axis=1)
POKEMONDF2=POKEMONDF2.drop('Type', axis=1)

# %%
POKEMONDF2
# Out:
#                           Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Bulbasaur                   318   45      49       49       65       65
# Ivysaur                     405   60      62       63       80       80
# Venusaur                    525   80      82       83      100      100
# Venusaur  Mega Venusaur     625   80     100      123      122      120
# Charmander                  309   39      52       43       60       50
# ...                         ...  ...     ...      ...      ...      ...
# Iron Crown                  590   90      72      100      122      108
# Terapagos  Normal Form      450   90      65       85       65       85
# Terapagos  Terastal Form    600   95      95      110      105      110
# Terapagos  Stellar Form     700  160     105      110      130      110
# Pecharunt                   600   88      88      160       88       88
#
#                           Speed   Type1    Type2
# Name
# ...

# %% [markdown]
# (2) 이브이 진화별 스텟 변화

# %%
eeves=POKEMONDF.loc[['Eevee','Vaporeon','Jolteon','Flareon','Espeon','Umbreon','Leafeon','Glaceon','Sylveon','Charmeleon','Charizard']]
eeves
# Out:
#                     Type  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# Name
# Eevee             Normal    325   55      55       50       45       65     55
# Vaporeon           Water    525  130      65       60      110       95     65
# Jolteon         Electric    525   65      65       60      110       95    130
# Flareon             Fire    525   65     130       60       95      110     65
# Espeon           Psychic    525   65      65       60      130       95    110
# Umbreon             Dark    525   95      65      110       60      130     65
# Leafeon            Grass    525   65     110      130       60       65     95
# Glaceon              Ice    525   65      60      110      130       95     65
# Sylveon            Fairy    525   95      65       65      110      130     60
# Charmeleon          Fire    405   58      64       58       80       65     80
# Charizard   Fire  Flying    534   78      84       78      109       85    100

# %%
#오.... 이브이 진화체 타입의 총합치는 전부 525로 일치 한다....

# %% [markdown]
# (3) 스타팅 포켓몬 연구

# %%
startings=POKEMONDF.loc[['Bulbasaur','Ivysaur','Venusaur','Charmander','Charmeleon','Charizard','Squirtle','Wartortle','Blastoise',
                         'Chikorita','Bayleef','Meganium','Cyndaquil','Quilava','Typhlosion','Totodile','Croconaw','Feraligatr',
                         'Treecko','Grovyle','Sceptile','Torchic','Combusken','Blaziken','Mudkip','Marshtomp','Swampert',
                         'Turtwig','Grotle','Torterra','Chimchar','Monferno','Infernape','Piplup','Prinplup','Empoleon',
                         'Snivy','Servine','Serperior','Tepig','Pignite','Emboar','Oshawott','Dewott','Samurott',
                         'Chespin','Quilladin','Chesnaught','Fennekin','Braixen','Delphox','Froakie','Frogadier','Greninja',
                         'Rowlet','Dartrix','Decidueye','Litten','Torracat','Incineroar','Popplio','Brionne','Primarina',
                         'Grookey','Thwackey','Rillaboom','Scorbunny','Raboot','Cinderace','Sobble','Drizzile','Inteleon',
                         'Sprigatito','Floragato','Meowscarada','Fuecoco','Crocalor','Skeledirge','Quaxly','Quaxwell','Quaquaval'
                         
                        ]]

# %%
startings
# Out:
#                        Type  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Bulbasaur     Grass  Poison    318   45      49       49       65       65
# Ivysaur       Grass  Poison    405   60      62       63       80       80
# Venusaur      Grass  Poison    525   80      82       83      100      100
# Charmander             Fire    309   39      52       43       60       50
# Charmeleon             Fire    405   58      64       58       80       65
# ...                     ...    ...  ...     ...      ...      ...      ...
# Crocalor               Fire    411   81      55       78       90       58
# Skeledirge      Fire  Ghost    530  104      75      100      110       75
# Quaxly                Water    310   55      65       45       50       45
# Quaxwell              Water    410   70      85       65       65       60
# Quaquaval   Water  Fighting    530   85     120       80       85       75
#
#             Speed
# Name
# Bulbasaur      45
# ...

# %%
startco=startings.corr(numeric_only=True)
startco
correlationstart=startco[["Total","HP","Attack","Defense","Sp. Atk","Sp. Def","Speed"]]
correlationstart
# Out:
#             Total        HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# Total    1.000000  0.846244  0.803361  0.751548  0.769716  0.800793  0.609925
# HP       0.846244  1.000000  0.803208  0.747624  0.563347  0.591250  0.246048
# Attack   0.803361  0.803208  1.000000  0.602924  0.408291  0.460176  0.404941
# Defense  0.751548  0.747624  0.602924  1.000000  0.353849  0.717855  0.142965
# Sp. Atk  0.769716  0.563347  0.408291  0.353849  1.000000  0.643925  0.510266
# Sp. Def  0.800793  0.591250  0.460176  0.717855  0.643925  1.000000  0.325765
# Speed    0.609925  0.246048  0.404941  0.142965  0.510266  0.325765  1.000000

# %%
allco=POKEMONDF.corr(numeric_only=True)
allco
correlationall=allco[["Total","HP","Attack","Defense","Sp. Atk","Sp. Def","Speed"]]

# %%
# importing libraries and dataset
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
import seaborn as sns

# %%
sns.heatmap(correlationall)
# Out:
# <Axes: >

# %%
# 알수 있는 것 :속도와 특수공격의 비례관계
#               hp와 방어력,특수방어간의 관

# %% [markdown]
# (4) 포켓몬 단일/멀티타입 구분 함수

# %%
POKEMONgoDF
# Out:
#       id  num  name                                               img  \
# 0      1    1  이상해씨  http://www.serebii.net/pokemongo/pokemon/001.png
# 1      2    2  이상해풀  http://www.serebii.net/pokemongo/pokemon/002.png
# 2      3    3  이상해꽃  http://www.serebii.net/pokemongo/pokemon/003.png
# 3      4    4   파이리  http://www.serebii.net/pokemongo/pokemon/004.png
# 4      5    5   리자드  http://www.serebii.net/pokemongo/pokemon/005.png
# ..   ...  ...   ...                                               ...
# 146  147  147    미뇽  http://www.serebii.net/pokemongo/pokemon/147.png
# 147  148  148    신뇽  http://www.serebii.net/pokemongo/pokemon/148.png
# 148  149  149   망나뇽  http://www.serebii.net/pokemongo/pokemon/149.png
# 149  150  150    뮤츠  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151     뮤  http://www.serebii.net/pokemongo/pokemon/151.png
#
#          type  height    weight           candy    egg  \
# 0       풀 / 독  0.71 m    6.9 kg      25 이상해씨 캔디   2 km
# ...

# %%
POKEMONgoDF[['name','type','candy','multipliers',]]
# Out:
#      name      type           candy                 multipliers
# 0    이상해씨     풀 / 독      25 이상해씨 캔디                        1.58
# 1    이상해풀     풀 / 독     100 이상해씨 캔디                  [1.2, 1.6]
# 2    이상해꽃     풀 / 독              없음                        None
# 3     파이리        불꽃       25 파이리 캔디                        1.65
# 4     리자드        불꽃      100 파이리 캔디                        1.79
# ..    ...       ...             ...                         ...
# 146    미뇽       드래곤        25 미뇽 캔디  [1.83, 1.8399999999999999]
# 147    신뇽       드래곤  100 Dratini 캔디                        2.05
# 148   망나뇽  드래곤 / 비행              없음                        None
# 149    뮤츠       에스퍼              없음                        None
# 150     뮤       에스퍼              없음                        None
#
# [151 rows x 4 columns]

# %%
def type_distibuter(type):
    if " " in type:
        return 'double type'
    return 'single type'

# %%
TYPE_DISTRIBUTE=POKEMONDF['Type'].apply(type_distibuter)
TYPE_DISTRIBUTE600=E600DF['Type'].apply(type_distibuter)

# %%
TYPE_DISTRIBUTE
# Out:
# Name
# Bulbasaur                   double type
# Ivysaur                     double type
# Venusaur                    double type
# Venusaur  Mega Venusaur     double type
# Charmander                  single type
#                                ...
# Iron Crown                  double type
# Terapagos  Normal Form      single type
# Terapagos  Terastal Form    single type
# Terapagos  Stellar Form     single type
# Pecharunt                   double type
# Name: Type, Length: 1215, dtype: object

# %% [markdown]
# ### (4) egg로 건강챙기기>>...

# %%
NEWDATAGO=POKEMONgoDF[['name','type','candy','egg','multipliers','weaknesses','weight']]

# %%
NEWDATAGO
# Out:
#      name      type           candy    egg                 multipliers  \
# 0    이상해씨     풀 / 독      25 이상해씨 캔디   2 km                        1.58
# 1    이상해풀     풀 / 독     100 이상해씨 캔디   None                  [1.2, 1.6]
# 2    이상해꽃     풀 / 독              없음   None                        None
# 3     파이리        불꽃       25 파이리 캔디   2 km                        1.65
# 4     리자드        불꽃      100 파이리 캔디   None                        1.79
# ..    ...       ...             ...    ...                         ...
# 146    미뇽       드래곤        25 미뇽 캔디  10 km  [1.83, 1.8399999999999999]
# 147    신뇽       드래곤  100 Dratini 캔디   None                        2.05
# 148   망나뇽  드래곤 / 비행              없음   None                        None
# 149    뮤츠       에스퍼              없음   None                        None
# 150     뮤       에스퍼              없음   None                        None
#
#              weaknesses    weight
# 0     [불꽃, 얼음, 비행, 에스퍼]    6.9 kg
# 1     [불꽃, 얼음, 비행, 에스퍼]   13.0 kg
# ...

# %%
# egg 수치는 진화를 위해 필요한 거리 길이이다.....

# %%
NEWDATAGO['egg']
# Out:
# 0       2 km
# 1       None
# 2       None
# 3       2 km
# 4       None
#        ...
# 146    10 km
# 147     None
# 148     None
# 149     None
# 150     None
# Name: egg, Length: 151, dtype: object

# %%
NEWDATAGO['egg'].value_counts()
# Out:
# egg
# 5 km     42
# 10 km    17
# 2 km     14
# Name: count, dtype: int64

# %%
#일단 egg를 범주타입으로 바꿔야 한다.

# %%
NEWDATAGO['egg'].astype('category')
# Out:
# 0       2 km
# 1        NaN
# 2        NaN
# 3       2 km
# 4        NaN
#        ...
# 146    10 km
# 147      NaN
# 148      NaN
# 149      NaN
# 150      NaN
# Name: egg, Length: 151, dtype: category
# Categories (3, object): ['10 km', '2 km', '5 km']

# %%
# 종류가 3종류이다.....

# %%
NEWDATAGO['egg']=='5 km'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 146    False
# 147    False
# 148    False
# 149    False
# 150    False
# Name: egg, Length: 151, dtype: bool

# %%
NEWDATAGO[NEWDATAGO['egg']=='5 km']
# Out:
#      name     type       candy   egg  \
# 22     아보        독    50 아보 캔디  5 km
# 26   모래두지        땅  50 모래두지 캔디  5 km
# 28   니드런♀        독  25 니드런♀ 캔디  5 km
# 31   니드런♂        독  25 니드런♂ 캔디  5 km
# 36   식스테일       불꽃  50 식스테일 캔디  5 km
# 42    뚜벅쵸    풀 / 독   25 뚜벅쵸 캔디  5 km
# 45    파라스   벌레 / 풀   50 파라스 캔디  5 km
# 47     콘팡   벌레 / 독    50 콘팡 캔디  5 km
# 49    디그다        땅   50 디그다 캔디  5 km
# 51     나옹       노말    50 나옹 캔디  5 km
# 53   고라파덕        물  50 고라파덕 캔디  5 km
# 55     망키       격투    50 망키 캔디  5 km
# 57     가디       불꽃    50 가디 캔디  5 km
# 59    발챙이        물   25 발챙이 캔디  5 km
# 62    캐이시      에스퍼   25 캐이시 캔디  5 km
# 65    알통몬       격투   25 알통몬 캔디  5 km
# 68    모다피    풀 / 독   25 모다피 캔디  5 km
# 71    왕눈해    물 / 독   50 왕눈해 캔디  5 km
# 76    포니타       불꽃   50 포니타 캔디  5 km
# 78     야돈  물 / 에스퍼    50 야돈 캔디  5 km
# 80     코일       전기    50 코일 캔디  5 km
# 82    파오리  노말 / 비행          없음  5 km
# 83     두두  노말 / 비행    50 두두 캔디  5 km
# 85     쥬쥬        물    50 쥬쥬 캔디  5 km
# ...

# %%
km10=NEWDATAGO[NEWDATAGO['egg']=='10 km']

# %%
km5=NEWDATAGO[NEWDATAGO['egg']=='5 km']

# %%
km2=NEWDATAGO[NEWDATAGO['egg']=='2 km']

# %%
km2['type'].value_counts()
# Out:
# type
# 노말         3
# 물          2
# 노말 / 비행    2
# 풀 / 독      1
# 불꽃         1
# 벌레         1
# 벌레 / 독     1
# 전기         1
# 독 / 비행     1
# 바위 / 땅     1
# Name: count, dtype: int64

# %%
km5['type'].value_counts()
# Out:
# type
# 물          8
# 독          5
# 노말         5
# 불꽃         3
# 땅          3
# 격투         2
# 노말 / 비행    2
# 전기         2
# 에스퍼        2
# 풀 / 독      2
# 벌레 / 독     1
# 물 / 독      1
# 물 / 에스퍼    1
# 벌레 / 풀     1
# 고스트 / 독    1
# 풀 / 에스퍼    1
# 땅 / 바위     1
# 풀          1
# Name: count, dtype: int64

# %%
km10['type'].value_counts()
# Out:
# type
# 노말          3
# 격투          2
# 바위 / 물      2
# 바위 / 땅      1
# 에스퍼         1
# 벌레 / 비행     1
# 얼음 / 에스퍼    1
# 전기          1
# 불꽃          1
# 벌레          1
# 물 / 얼음      1
# 바위 / 비행     1
# 드래곤         1
# Name: count, dtype: int64

# %%
#다 더하면 개수 나옴

# %%
sum(NEWDATAGO['egg']=='5 km')
# Out:
# 42

# %%
km10=NEWDATAGO[NEWDATAGO['egg']=='10 km']

# %%
sum(NEWDATAGO['egg']=='10 km')
# Out:
# 17

# %%
km2=NEWDATAGO[NEWDATAGO['egg']=='2 km']

# %%
sum(NEWDATAGO['egg']=='2 km')
# Out:
# 14

# %%
import matplotlib.pyplot as plt           #그래프 관련 모듈
import matplotlib as mpl                  #패키지 관련 
import matplotlib.font_manager as fm      #패키지 리소스 즉 자원 중 폰트 관련
                                        
import pandas as pd

# %%
# 폰트 경로 저장
font_path=r'C:\Windows\Fonts\gulim.ttc'

# %%
#matplotlib 패키지에 한글 폰트 설정
myFont=fm.FontProperties(fname=font_path).get_name()
mpl.rc('font', family=myFont)

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ["42 고 10km",
          "17 중 5km",
          "14 저 2km",
          ]

data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d} 종류)"


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="부화에 필요한 거리",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("포켓몬 알을 까기 위한 조깅 거리 ")

plt.show()

# %% [markdown]
# (5) 600족의 비밀

# %%
E600DF
# Out:
#                                        Type  Total   HP  Attack  Defense  \
# Name
# Alakazam  Mega Alakazam             Psychic    600   55      50       65
# Gengar  Mega Gengar           Ghost  Poison    600   60      65       80
# Pinsir  Mega Pinsir             Bug  Flying    600   65     155      120
# Dragonite                    Dragon  Flying    600   91     134       95
# Mew                                 Psychic    600  100     100      100
# Scizor  Mega Scizor              Bug  Steel    600   70     150      140
# Heracross  Mega Heracross     Bug  Fighting    600   80     185      115
# Houndoom  Mega Houndoom          Dark  Fire    600   75      90       90
# Tyranitar                        Rock  Dark    600  100     134      110
# Celebi                       Psychic  Grass    600  100     100      100
# Salamence                    Dragon  Flying    600   95     135       80
# Metagross                    Steel  Psychic    600   80     135      130
# ...

# %%
REAL600=E600DF.loc[["Dragonite","Tyranitar","Salamence","Metagross","Garchomp","Hydreigon",
"Goodra","Kommo-o","Dragapult","Baxcalibur"]]

# %%
REAL600
# Out:
#                         Type  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Dragonite     Dragon  Flying    600   91     134       95      100      100
# Tyranitar         Rock  Dark    600  100     134      110       95      100
# Salamence     Dragon  Flying    600   95     135       80      110       80
# Metagross     Steel  Psychic    600   80     135      130       95       90
# Garchomp      Dragon  Ground    600  108     130       95       80       85
# Hydreigon       Dark  Dragon    600   92     105       90      125       90
# Goodra                Dragon    600   90     100       70      110      150
# Kommo-o     Dragon  Fighting    600   75     110      125      100      105
# Dragapult      Dragon  Ghost    600   88     120       75      100       75
# Baxcalibur       Dragon  Ice    600  115     145       92       75       86
#
#             Speed
# Name
# Dragonite      80
# Tyranitar      61
# Salamence     100
# Metagross      70
# Garchomp      102
# ...

# %%
REAL600['Type'].str.contains('Dragon')
# Out:
# Name
# Dragonite      True
# Tyranitar     False
# Salamence      True
# Metagross     False
# Garchomp       True
# Hydreigon      True
# Goodra         True
# Kommo-o        True
# Dragapult      True
# Baxcalibur     True
# Name: Type, dtype: bool

# %% [markdown]
# 10종류 중 8마리가 드래곤 타입....

# %%
realco=REAL600.corr(numeric_only=True)
realco
# Out:
#          Total        HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# Total      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# HP         NaN  1.000000  0.515101 -0.374874 -0.544503 -0.233607  0.025338
# Attack     NaN  0.515101  1.000000  0.238826 -0.682393 -0.577676 -0.179241
# Defense    NaN -0.374874  0.238826  1.000000 -0.263043 -0.134032 -0.561443
# Sp. Atk    NaN -0.544503 -0.682393 -0.263043  1.000000  0.257979  0.097894
# Sp. Def    NaN -0.233607 -0.577676 -0.134032  0.257979  1.000000 -0.476642
# Speed      NaN  0.025338 -0.179241 -0.561443  0.097894 -0.476642  1.000000

# %%
correlation600=realco[["HP","Attack","Defense","Sp. Atk","Sp. Def","Speed"]]
CO600=correlation600.loc[["HP","Attack","Defense","Sp. Atk","Sp. Def","Speed"]]

# %%
CO600
# Out:
#                HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# HP       1.000000  0.515101 -0.374874 -0.544503 -0.233607  0.025338
# Attack   0.515101  1.000000  0.238826 -0.682393 -0.577676 -0.179241
# Defense -0.374874  0.238826  1.000000 -0.263043 -0.134032 -0.561443
# Sp. Atk -0.544503 -0.682393 -0.263043  1.000000  0.257979  0.097894
# Sp. Def -0.233607 -0.577676 -0.134032  0.257979  1.000000 -0.476642
# Speed    0.025338 -0.179241 -0.561443  0.097894 -0.476642  1.000000

# %%
sns.heatmap(CO600)
# Out:
# <Axes: >

# %% [markdown]
# (7) 세대별 분류
